# %%
import time as t
print("\t\t\t\t\tWelcome to abc Bank")
print("\t\t\t\t\t\t\t\t\tplease Insert your card")
t.sleep(2)
class Bank:
    
    def __init__(self):
        self.__acnumber=123456789
        self.__balance=10000
        self.name="Rajesh"
        self.pin_counter=0
        self.__pin=1234
        if self.pin_counter==0:
            var1=int(input("please enter your pin sent by bank"))
            if var1==self.__pin: 
                self.set_pin(int(input("enter you new pin")))
            else:
                print("you entered  wrong pin")
        self.pin_verify()
    def set_pin(self,pin):
        self.__pin=pin
        self.pin_counter=self.pin_counter+1
    def balnce_info(self):
        print(f"Bank Balance {self.__balance}")
    def show_balance(self):
        print(f"Account Number {self.__acnumber}")
        print(f"Bank Balance {self.__balance}")
        print(f"Acccount Name {self.name}")
    def pin_verify(self):
        num_of_tries = 3
        while(num_of_tries!=0):
            try :
                pin=int(input("\t\t\t\tEnter your Pin"))
            except Exception as e:
                print(e)
            if pin==self.__pin:
                print("\t\t\t\tPin Verified")
                t.sleep(2)
                break
            else:
                num_of_tries-=1
                print(f"Pin not verified. no. of tries left {num_of_tries} ")
                t.sleep(1)
                if num_of_tries==0:
                    pin==self.__pin
                    print("Password reset successfully")
                    break
     
        if pin==self.__pin:
            print("""
                                      1. Account Info
                                      2. Withdrawl Money
                                      3. Deposit Money
                                      4. Change your pin
                                      5. Exit
                      """)
        
        
            select=int(input("\t\t\t\tSelect Number"))
            if select==1:
#                 print(f"Account Number {self.__acnumber}")
#                 print(f"Bank Balance {self.__balance}")
#                 print(f"Acccount Name {self.name}")
                  self.show_balance()
            elif select==2:
                withdraw_amt=int(input("Enter the amount for withdrawl"))
                if withdraw_amt<=self.__balance:
                    self.__balance-= withdraw_amt
                    print(f"Bank Balance {self.__balance}")
                else:
                    print('Insufficient Balance')
            elif select==3:
                deposit_amt=int(input("Enter the amount for deposit"))
                self.__balance+=deposit_amt
                print(f"Bank Balance {self.__balance}")
            elif select ==4:
                self.__set_pin(int(input("Enter your new pin")))
            elif select==5:
                print(f"\t\t\t\tThank You for using out ATM")
                t.sleep(2)
obj=Bank()
#obj.pin_verify()
obj.show_balance()
# Out:
# 					Welcome to abc Bank
# 									please Insert your card
# please enter your pin sent by bank1234
# enter you new pin4779
# 				Enter your Pin4779
# 				Pin Verified
#
#                                       1. Account Info
#                                       2. Withdrawl Money
#                                       3. Deposit Money
#                                       4. Change your pin
#                                       5. Exit
#
# 				Select Number5
# 				Thank You for using out ATM
